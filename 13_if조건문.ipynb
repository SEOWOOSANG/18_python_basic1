# %%
# if 조건문 사용하기
# if 조건식:
#     코드

x = 10
if x == 10:
    print("10입니다.")
# Out:
# 10입니다.

# %%
x = 10
if x == 10:
print("10입니다.")
# Out:
#   Cell In[6], line 3
#     print("10입니다.")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
# if 조건문을 사용할 때 주의할 점

if x = 10:
# Out:
#   Cell In[5], line 3
#     if x = 10:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
# if 조건문에서 코드를 생략하기

x = 10
if x == 10:
    pass

# %%
# if 조건문과 들여쓰기

x = 10

if x == 10:
    print("x에 들어있는 숫자는")
        print("10입니다.")
# Out:
#   Cell In[10], line 7
#     print("10입니다.")
#     ^
# IndentationError: unexpected indent

# %%
x = 10

if x == 10:
    print("x에 들어있는 숫자는")
print("10입니다.")
# Out:
# x에 들어있는 숫자는
# 10입니다.

# %%
# 중첩 if 조건문 사용하기

x = 15

if x >= 10:
    print("10 이상입니다.")

    if x == 15:
        print("15입니다.")

        if x == 20:
            print("20입니다.")
# Out:
# 10 이상입니다.
# 15입니다.

# %%
# 사용자가 입력한 값에 if 조건문 사용하기

x = int(input())

if x == 10:
    print("10입니다.")

if x == 20:
    print("20입니다.")
# Out:
# 10입니다.

# %%
x = 5

if x != 10:
    print("ok")
# Out:
# ok

# %%
x = int(input())
y = input()

if y == "Cash3000":
    print(x - 3000)

if y == "Cash5000":
    print(x - 5000)
# Out:
# 24000

# %%
price = int(input())
coupon = input()

if b == "Cash3000":
    print(f"{"price" - 3000}")

if b == "Cash5000":
    print(f"{"price" - 5000}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 8
#       4 if b == "Cash3000":
#       5     print(f"{"price" - 3000}")
#       6
#       7 if b == "Cash5000":
# ----> 8     print(f"{"price" - 5000}")
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'
