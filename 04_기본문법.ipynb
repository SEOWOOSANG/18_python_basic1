# %%
# 세미콜론

print("Hello world");
# Out:
# Hello world

# %%
print("hello"); print("1234")
# Out:
# hello
# 1234

# %%
# 한 줄 주석

print("Hello world")
# Out:
# Hello world

# %%
# 블록 주석

# print("Hello world")
# print("Hello world")
# print("Hello world")

# %%
# 들여쓰기
a = 5
if a == 10:
    print("10입니다")
    print("5입니다")
